# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] ='/content'
# !kaggle datasets download -d johnsmith88/heart-disease-dataset
# !unzip \*.zip && rm *.zip
# Out:
# ...
#   0% 0.00/6.18k [00:00<?, ?B/s]
# 100% 6.18k/6.18k [00:00<00:00, 12.4MB/s]
# Archive:  heart-disease-dataset.zip
#   inflating: heart.csv

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix

# %%
# Load the Heart Disease dataset
data = pd.read_csv('/content/heart.csv')

# %%
# Define Hassanat kNN algorithm
class HassanatKNN(KNeighborsClassifier):
    def __init__(self, n_neighbors=5, **kwargs):
        super().__init__(n_neighbors=n_neighbors, **kwargs)

    def _weight_func(self, distances):
        return 1 / (distances + 1)  # Hassanat weighting function

    def predict(self, X):
        neigh_dist, neigh_ind = self.kneighbors(X)
        weights = self._weight_func(neigh_dist)
        _y = self._y
        classes_ = self.classes_

        n_outputs = len(classes_)
        n_samples = X.shape[0]

        y_pred = np.empty((n_samples, n_outputs), dtype=classes_.dtype)
        for k, classes_k in enumerate(classes_):
            mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
            mode = np.asarray(mode.ravel(), dtype=np.intp)
            y_pred[:, k] = classes_k.take(mode)

        return y_pred

# %%
# !pip install scipy

# %%
from scipy import stats

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import numpy as np
from scipy import stats

# %%
# Print the signature of the hknn.predict method
print(hknn.predict.__doc__)
# Out:
# None

# %%
# Print the shape of X_test_scaled
print(X_test_scaled.shape)

# Print the first 5 rows of X_test_scaled
print(X_test_scaled.head())
# Out:
# (205, 13)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-f4db6c2187c9> in <cell line: 5>()
#       3
#       4 # Print the first 5 rows of X_test_scaled
# ----> 5 print(X_test_scaled.head())
#
# AttributeError: 'numpy.ndarray' object has no attribute 'head'

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from imblearn.pipeline import Pipeline

# Load the data
data = pd.read_csv('/content/heart.csv')  # Replace 'your_data.csv' with the actual file path

# Separate features and target variable
X = data.drop(columns=['target'])
y = data['target']

# Step 2: Feature Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Step 3: Splitting Data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Step 4: Model Training
k = 5  # Number of neighbors
over_sampler = SMOTE(sampling_strategy='auto', random_state=42)
under_sampler = RandomUnderSampler(sampling_strategy='auto', random_state=42)
model = Pipeline([
    ('over_sampler', over_sampler),
    ('under_sampler', under_sampler),
    ('clf', KNeighborsClassifier(n_neighbors=k))
])
model.fit(X_train, y_train)

# Step 5: Model Evaluation
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# Accuracy: 0.848780487804878
# Precision: 0.8214285714285714
# Recall: 0.8932038834951457
# F1 Score: 0.8558139534883721
